# %% [markdown]
# ### Raw Data: Omicron daily cases by country (COVID-19 variant) in Kaggle

# %% [markdown]
# Tracking the progression of the new omicron COVID-19 variant
# The data
# location- this is the country for which the variants information is provided;
# date - date for the data entry;
# variant - this is the variant corresponding to this data entry;
# num_sequences - the number of sequences processed (for the country, variant and date);
# perc_sequences - percentage of sequences from the total number of sequences (for the country, variant and date);
# numsequencestotal - total number of sequences (for the country, variant and date);
# Acknowledgements

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from numpy import nan as NA
import matplotlib.pyplot as plt # to seaborn
import seaborn as sns

# %%
data = pd.read_csv("C:/lily_git/covid-variants.csv")

# %%
data
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 0         Angola  2020-07-06           Alpha              0             0.0
# 1         Angola  2020-07-06       B.1.1.277              0             0.0
# 2         Angola  2020-07-06       B.1.1.302              0             0.0
# 3         Angola  2020-07-06       B.1.1.519              0             0.0
# 4         Angola  2020-07-06         B.1.160              0             0.0
# ...          ...         ...             ...            ...             ...
# 100411  Zimbabwe  2021-11-01         Omicron              0             0.0
# 100412  Zimbabwe  2021-11-01   S:677H.Robin1              0             0.0
# 100413  Zimbabwe  2021-11-01  S:677P.Pelican              0             0.0
# 100414  Zimbabwe  2021-11-01          others              0             0.0
# 100415  Zimbabwe  2021-11-01         non_who              0             0.0
#
#         num_sequences_total
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100416 entries, 0 to 100415
# Data columns (total 6 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   location             100416 non-null  object
#  1   date                 100416 non-null  object
#  2   variant              100416 non-null  object
#  3   num_sequences        100416 non-null  int64
#  4   perc_sequences       100416 non-null  float64
#  5   num_sequences_total  100416 non-null  int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 4.6+ MB

# %%
data.describe()
# Out:
#        num_sequences  perc_sequences  num_sequences_total
# count  100416.000000   100416.000000        100416.000000
# mean       72.171676        6.154355          1509.582457
# std      1669.262169       21.898989          8445.291772
# min         0.000000       -0.010000             1.000000
# 25%         0.000000        0.000000            12.000000
# 50%         0.000000        0.000000            59.000000
# 75%         0.000000        0.000000           394.000000
# max    142280.000000      100.000000        146170.000000

# %%
data['location'].value_counts('location',None)
# Out:
# Angola           0.006692
# Argentina        0.010516
# Aruba            0.005975
# Australia        0.010516
# Austria          0.010277
#                    ...
# United States    0.010755
# Uruguay          0.005736
# Vietnam          0.005019
# Zambia           0.008126
# Zimbabwe         0.006692
# Name: location, Length: 121, dtype: float64

# %%
data_pivot = data.pivot_table(index = 'date', columns = "location", values = 'num_sequences')
data_pivot
# Out:
# location      Angola  Argentina      Aruba   Australia    Austria    Bahrain  \
# date
# 2020-05-11       NaN  12.583333        NaN   12.333333   2.833333        NaN
# 2020-05-25       NaN  13.916667        NaN    8.583333   3.416667        NaN
# 2020-06-08       NaN   5.583333        NaN    7.833333   0.083333   0.083333
# 2020-06-22       NaN   6.583333        NaN   14.333333   0.083333   0.166667
# 2020-07-06  0.250000   5.250000        NaN   67.833333   0.166667   0.916667
# 2020-07-20       NaN   9.416667        NaN  227.750000   0.916667        NaN
# 2020-08-03       NaN   8.583333        NaN  348.583333   0.750000   0.250000
# 2020-08-17       NaN   9.416667   0.333333  251.666667   1.833333        NaN
# 2020-08-31  0.041667  11.500000   0.083333  165.583333   3.666667   0.250000
# 2020-09-14       NaN   4.166667        NaN   64.166667   2.916667   0.166667
# 2020-09-28  0.458333   4.666667        NaN   26.916667   3.250000   0.166667
# ...

# %% [markdown]
# https://data-make.tistory.com/138
